# %% [markdown]
# # IPBMA_3: Phantom Simulation

# %% [markdown]
# ### Author: LIU CONG 、 Ulloa Ferrer,Leonardo

# %%
import numpy as np 
import matplotlib.pyplot as plt
import sys
import os

phantomsFnc =  os.path.join(sys.path[0], 'auxFiles', 'phantomsFnc.py')
IoFnc =  os.path.join(sys.path[0], 'auxFiles', 'IoFnc.py')

# %run {phantomsFnc}
# %run {IoFnc}

# %% [markdown]
# ## cube_phantom_h

# %%
edge_size = 256
energy = 40

phantom_h = cube_phantom_h(edge_size, energy)

# %%
slice_phantom_h_1 = phantom_h[:, 128, :]
# print(slice_1)

plt.imshow(slice_phantom_h_1, cmap='gray')
plt.show()

# %%
nLine = 128
line = getLine(slice_phantom_h_1, nLine)
# print(line)
plt.plot(line)
plt.show()

# %%
slice_phantom_h_2 = phantom_h[:, :, 70]

plt.imshow(slice_phantom_h_2, cmap='gray')
plt.show()

# %%
nLine = 128

line = getLine(slice_phantom_h_2, nLine)
plt.plot(line)

# %% [markdown]
# ## cube_phantom_nh

# %%
phantom_nh = cube_phantom_nh(edge_size, energy)
# print(phantom_nh)

slice_cube_phantom_nh_1 = phantom_nh[:, 128, :]
# print(slice_1)

plt.imshow(slice_cube_phantom_nh_1, cmap='gray')
plt.show()

# %%
line = getLine(slice_cube_phantom_nh_1, nLine)
# print(line)
plt.plot(line)

# %%
slice_cube_phantom_nh_2 = phantom_nh[:, :, 70]
# print(slice_2)
plt.imshow(slice_cube_phantom_nh_2, cmap='gray')
plt.show()

# %%
line = getLine(slice_cube_phantom_nh_2, nLine)
# print(line)
plt.plot(line)

# %% [markdown]
# ### breast_phantom

# %%
breast_phantom = breast_phantom(edge_size, energy)

# %%
slice_breast_phantom_1 = breast_phantom[:, 128, :]
plt.imshow(slice_breast_phantom_1, cmap="gray")
plt.show()

# %%
nLine = 128
line = getLine(slice_breast_phantom_1, nLine)

plt.plot(line)

# %%
slice_2 = breast_phantom[:, :, 70]

# %%
plt.imshow(slice_2, cmap="gray")
plt.show()

# %%
nLine = 128
line = getLine(slice_2, nLine)
plt.plot(line)

# %%
import numpy as np 
import matplotlib.pyplot as plt
from utils import utils 
import importlib
import sys
import os
py_file =  os.path.join(sys.path[0], 'phantomsFnc.py')

# %run {py_file}

# %% [markdown]
# ## cube_phantom_h

# %%
edge_size = 256
energy = 40

phantom_h = cube_phantom_h(edge_size, energy)

# %%
slice_1 = phantom_h[:, 128, :]
# print(slice_1)

plt.imshow(slice_1, cmap='gray')
plt.show()

# %%
nLine = 128
line = utils.getLine(slice_1, nLine)
# print(line)
plt.plot(line)
plt.show()

# %%
slice_2 = phantom_h[:, :, 70]

plt.imshow(slice_2, cmap='gray')
plt.show()

# %%
nLine = 128

line = utils.getLine(slice_2, nLine)
plt.plot(line)

# %% [markdown]
# ## cube_phantom_nh

# %%
phantom_nh = cube_phantom_nh(edge_size, energy)
# print(phantom_nh)

slice_1 = phantom_nh[:, 128, :]
# print(slice_1)

plt.imshow(slice_1, cmap='gray')
plt.show()

# %%
line = utils.getLine(slice_1, nLine)
# print(line)
plt.plot(line)

# %%
slice_2 = phantom_nh[:, :, 70]
# print(slice_2)
plt.imshow(slice_2, cmap='gray')
plt.show()

# %%
line = utils.getLine(slice_2, nLine)
# print(line)
plt.plot(line)

# %%
import numpy as np 
import matplotlib.pyplot as plt
from utils import utils
import importlib
import sys
import os
py_file =  os.path.join(sys.path[0], 'phantomsFnc.py')

# %run {py_file}

# %%
edge_size = 4
energy = 40

p = cube_phantom_h(edge_size, energy)
print(p)

# plot image
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.voxels(p, facecolors='blue', edgecolor='k')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# [[[0.284928 0.284928 0.284928 0.284928]
#   [0.284928 0.284928 0.284928 0.284928]
#   [0.284928 0.284928 0.284928 0.284928]
#   [0.284928 0.284928 0.284928 0.284928]]
#
#  [[0.284928 0.284928 0.284928 0.284928]
#   [0.284928 1.27776  1.27776  0.284928]
#   [0.284928 1.27776  1.27776  0.284928]
#   [0.284928 0.284928 0.284928 0.284928]]
#
#  [[0.284928 0.284928 0.284928 0.284928]
#   [0.284928 1.27776  1.27776  0.284928]
#   [0.284928 1.27776  1.27776  0.284928]
#   [0.284928 0.284928 0.284928 0.284928]]
#
#  [[0.284928 0.284928 0.284928 0.284928]
#   [0.284928 0.284928 0.284928 0.284928]
#   [0.284928 0.284928 0.284928 0.284928]
#   [0.284928 0.284928 0.284928 0.284928]]]
